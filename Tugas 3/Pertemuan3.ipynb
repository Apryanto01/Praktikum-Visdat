# %% [markdown]
# ### Praktikum 3 Matplotib - Line Plot
# **Kelompok 18**
#
# *   Apriyanto (0110222256)
# *   Raydino Situmeang (0110222278)
# *   Deva Lubna Listya (0110222258)

# %% [markdown]
# # A. Line Plot Sederhana
# #

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Feb', 'Mar', 'Apr', 'May', 'Jun', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35]

# Line Plot dengan Matplotlib
print("A. Line Plot Sederhana (Penjualan Produk A)")
plt.figure(figsize=(8, 5))
plt.plot(months, product_A_sales, color=COLOR_A, marker='o', linestyle='-')
plt.title('Penjualan Produk A Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Penjualan Penjualan')
plt.show()
# Out:
# A. Line Plot Sederhana (Penjualan Produk A)

# %% [markdown]
# # B. Kustomisasi Line Plot

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot
plt.plot(months, product_A_sales, label='Product A', color='blue', linestyle='--', marker='o')
plt.plot(months, product_B_sales, label='Product B', color='red', linestyle='-', marker='x')

plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# # C. Menambahkan Multiple Lines
# #

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot
plt.plot(months, product_A_sales, label='Product A', marker='o')
plt.plot(months, product_B_sales, label='Product B', marker='x')
plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 50, 60, 55, 65, 70, 70] # Added one value to match months length
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 40] # Added one value to match months length

# Line Plot
plt.plot(months, product_A_sales, label='Product A Trend', linestyle='--', color='blue')
plt.plot(months, product_B_sales, label='Product B Trend', linestyle='--', color='red')
plt.title('Tren Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 50, 60, 55, 65, 70, 75] # Added one value to match months length
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 42] # Added one value to match months length

# Line Plot
# Membuat figure (fig) dan set sumbu (axs) dengan 2 baris dan 1 kolom
fig, axs = plt.subplots(2, 1, figsize=(10, 8))

# Plot for Product A (pada sumbu pertama, yaitu axs[0])
axs[0].plot(months, product_A_sales, label='Product A', color='blue', marker='o')
axs[0].set_title('Penjualan Produk A Per Bulan')
axs[0].set_xlabel('Bulan')
axs[0].set_ylabel('Jumlah Penjualan')
axs[0].legend()
axs[0].grid(True)

# Plot for Product B (pada sumbu kedua, yaitu axs[1])
axs[1].plot(months, product_B_sales, label='Product B', color='red', marker='x')
axs[1].set_title('Penjualan Produk B Per Bulan')
axs[1].set_xlabel('Bulan')
axs[1].set_ylabel('Jumlah Penjualan')
axs[1].legend()
axs[1].grid(True)

# Menyesuaikan tata letak subplots agar tidak tumpang tindih
plt.tight_layout()
plt.show()
